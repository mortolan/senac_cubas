# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
import bson
import pprint
from bson.son import SON

client = MongoClient('10.52.51.28', 27017)
for document in client.cubas.marcio.find({}):
    
    pprint.pprint(document)
    
client.close
# Out:
# {'ID': '1',
#  'NOME': 'Bitcoin',
#  'PRECO_BTC': 'BTC 1.00000000',
#  'PRECO_RS': 'R$ 15.167,27',
#  'VARIACAO': '1,44 %',
#  'VM': 'R$ 266.251.772.983',
#  'VT': 'R$ 29.354.938.531',
#  '_id': ObjectId('5c7185f8a887625d640ee033')}
# {'ID': '2',
#  'NOME': 'Ethereum',
#  'PRECO_BTC': 'BTC 0.03848889',
#  'PRECO_RS': 'R$ 583,29',
#  'VARIACAO': '4,66 %',
#  'VM': 'R$ 61.232.454.905',
#  'VT': 'R$ 14.927.356.228',
#  '_id': ObjectId('5c7185f8a887625d640ee034')}
# {'ID': '3',
#  'NOME': 'XRP',
#  'PRECO_BTC': 'BTC 0.00008079',
#  'PRECO_RS': 'R$ 1,22',
#  'VARIACAO': '1,51 %',
#  'VM': 'R$ 50.648.339.656',
#  'VT': 'R$ 1.935.427.319',
#  '_id': ObjectId('5c7185f8a887625d640ee035')}
# {'ID': '4',
#  'NOME': 'EOS',
#  'PRECO_BTC': 'BTC 0.00100494',
#  'PRECO_RS': 'R$ 15,23',
#  'VARIACAO': '4,70 %',
#  'VM': 'R$ 13.801.707.801',
#  'VT': 'R$ 4.728.614.199',
#  '_id': ObjectId('5c7185f8a887625d640ee036')}
# {'ID': '5',
#  'NOME': 'Litecoin',
#  'PRECO_BTC': 'BTC 0.01269835',
#  'PRECO_RS': 'R$ 192,44',
#  'VARIACAO': '3,77 %',
#  'VM': 'R$ 11.661.787.815',
#  'VT': 'R$ 4.315.569.490',
#  '_id': ObjectId('5c7185f8a887625d640ee037')}
# {'ID': '6',
#  'NOME': 'Bitcoin Cash',
#  'PRECO_BTC': 'BTC 0.03670761',
#  'PRECO_RS': 'R$ 556,29',
#  'VARIACAO': '2,98 %',
#  'VM': 'R$ 9.811.908.422',
#  'VT': 'R$ 1.119.337.246',
#  '_id': ObjectId('5c7185f8a887625d640ee038')}
# {'ID': '7',
#  'NOME': 'Tether',
#  'PRECO_BTC': 'BTC 0.00024770',
#  'PRECO_RS': 'R$ 3,75',
#  'VARIACAO': '-0,62 %',
#  'VM': 'R$ 7.588.070.706',
#  'VT': 'R$ 25.505.082.509',
#  '_id': ObjectId('5c7185f8a887625d640ee039')}
# {'ID': '8',
#  'NOME': 'Stellar',
#  'PRECO_BTC': 'BTC 0.00002279',
#  'PRECO_RS': 'R$ 0,35',
#  'VARIACAO': '2,53 %',
#  'VM': 'R$ 6.623.661.419',
#  'VT': 'R$ 361.447.846',
#  '_id': ObjectId('5c7185f8a887625d640ee03a')}
# {'ID': '9',
#  'NOME': 'TRON',
#  'PRECO_BTC': 'BTC 0.00000624',
#  'PRECO_RS': 'R$ 0,09',
#  'VARIACAO': '0,71 %',
#  'VM': 'R$ 6.308.665.919',
#  'VT': 'R$ 450.165.962',
#  '_id': ObjectId('5c7185f8a887625d640ee03b')}
# {'ID': '10',
#  'NOME': 'Binance Coin',
#  'PRECO_BTC': 'BTC 0.00262467',
#  'PRECO_RS': 'R$ 39,78',
#  'VARIACAO': '-1,04 %',
#  'VM': 'R$ 5.615.395.685',
#  'VT': 'R$ 315.846.342',
#  '_id': ObjectId('5c7185f8a887625d640ee03c')}
# {'ID': '11',
#  'NOME': 'Cardano',
#  'PRECO_BTC': 'BTC 0.00001175',
#  'PRECO_RS': 'R$ 0,18',
#  'VARIACAO': '3,92 %',
#  'VM': 'R$ 4.615.367.571',
#  'VT': 'R$ 74.116.730',
#  '_id': ObjectId('5c7185f8a887625d640ee03d')}
# {'ID': '12',
#  'NOME': 'Bitcoin SV',
#  'PRECO_BTC': 'BTC 0.01657381',
#  'PRECO_RS': 'R$ 251,17',
#  'VARIACAO': '1,42 %',
#  'VM': 'R$ 4.429.791.901',
#  'VT': 'R$ 284.494.885',
#  '_id': ObjectId('5c7185f8a887625d640ee03e')}
# {'ID': '19',
#  'NOME': 'SpankChain',
#  'PRECO_BTC': 'BTC 0.00043243',
#  'PRECO_RS': 'R$ 11,34',
#  'VARIACAO': '6.139,12 %',
#  'VM': 'R$ 3.401.748.601',
#  'VT': 'R$ 11.363',
#  '_id': ObjectId('5c7185f8a887625d640ee03f')}
# {'ID': '19',
#  'NOME': 'VeChain',
#  'PRECO_BTC': 'BTC 0.00021655',
#  'PRECO_RS': 'R$ 6,01',
#  'VARIACAO': '-10,19 %',
#  'VM': 'R$ 3.332.469.001',
#  'VT': 'R$ 11.904.579',
#  '_id': ObjectId('5c7185f8a887625d640ee040')}
# {'ID': '13',
#  'NOME': 'Monero',
#  'PRECO_BTC': 'BTC 0.01297736',
#  'PRECO_RS': 'R$ 197,03',
#  'VARIACAO': '0,90 %',
#  'VM': 'R$ 3.312.685.144',
#  'VT': 'R$ 265.086.670',
#  '_id': ObjectId('5c7185f8a887625d640ee041')}
# {'ID': '14',
#  'NOME': 'IOTA',
#  'PRECO_BTC': 'BTC 0.00007653',
#  'PRECO_RS': 'R$ 1,16',
#  'VARIACAO': '2,09 %',
#  'VM': 'R$ 3.229.639.465',
#  'VT': 'R$ 29.108.577',
#  '_id': ObjectId('5c7185f8a887625d640ee042')}
# {'ID': '15',
#  'NOME': 'Dash',
#  'PRECO_BTC': 'BTC 0.02170169',
#  'PRECO_RS': 'R$ 328,88',
#  'VARIACAO': '1,65 %',
#  'VM': 'R$ 2.843.913.789',
#  'VT': 'R$ 932.670.167',
#  '_id': ObjectId('5c7185f8a887625d640ee043')}
# {'ID': '16',
#  'NOME': 'Maker',
#  'PRECO_BTC': 'BTC 0.17524494',
#  'PRECO_RS': 'R$ 2.660,70',
#  'VARIACAO': '8,55 %',
#  'VM': 'R$ 2.660.697.121',
#  'VT': 'R$ 8.918.518',
#  '_id': ObjectId('5c7185f8a887625d640ee044')}
# {'ID': '15',
#  'NOME': 'empowr coin',
#  'PRECO_BTC': 'BTC 0.00000002',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '48,55 %',
#  'VM': 'R$ 2.304.137.767',
#  'VT': 'R$ 2.180',
#  '_id': ObjectId('5c7185f8a887625d640ee045')}
# {'ID': '17',
#  'NOME': 'NEO',
#  'PRECO_BTC': 'BTC 0.00229606',
#  'PRECO_RS': 'R$ 34,80',
#  'VARIACAO': '5,75 %',
#  'VM': 'R$ 2.261.748.539',
#  'VT': 'R$ 856.693.328',
#  '_id': ObjectId('5c7185f8a887625d640ee046')}
# {'ID': '18',
#  'NOME': 'Ethereum Classic',
#  'PRECO_BTC': 'BTC 0.00118106',
#  'PRECO_RS': 'R$ 17,90',
#  'VARIACAO': '1,92 %',
#  'VM': 'R$ 1.941.905.477',
#  'VT': 'R$ 852.879.616',
#  '_id': ObjectId('5c7185f8a887625d640ee047')}
# {'ID': '19',
#  'NOME': 'NEM',
#  'PRECO_BTC': 'BTC 0.00001145',
#  'PRECO_RS': 'R$ 0,17',
#  'VARIACAO': '5,45 %',
#  'VM': 'R$ 1.565.098.128',
#  'VT': 'R$ 74.257.362',
#  '_id': ObjectId('5c7185f8a887625d640ee048')}
# {'ID': '21',
#  'NOME': 'Iconomi',
#  'PRECO_BTC': 'BTC 0.00084725',
#  'PRECO_RS': 'R$ 13,96',
#  'VARIACAO': '1.558,16 %',
#  'VM': 'R$ 1.380.892.003',
#  'VT': 'R$ 22.362',
#  '_id': ObjectId('5c7185f8a887625d640ee049')}
# {'ID': '59',
#  'NOME': 'DNotes',
#  'PRECO_BTC': 'BTC 0.00026178',
#  'PRECO_RS': 'R$ 8,76',
#  'VARIACAO': '-0,57 %',
#  'VM': 'R$ 1.348.661.145',
#  'VT': 'R$ 1.842',
#  '_id': ObjectId('5c7185f8a887625d640ee04a')}
# {'ID': '20',
#  'NOME': 'Zcash',
#  'PRECO_BTC': 'BTC 0.01378807',
#  'PRECO_RS': 'R$ 208,95',
#  'VARIACAO': '1,96 %',
#  'VM': 'R$ 1.244.963.818',
#  'VT': 'R$ 736.545.195',
#  '_id': ObjectId('5c7185f8a887625d640ee04b')}
# {'ID': '21',
#  'NOME': 'Ontology',
#  'PRECO_BTC': 'BTC 0.00022911',
#  'PRECO_RS': 'R$ 3,47',
#  'VARIACAO': '15,34 %',
#  'VM': 'R$ 1.125.931.752',
#  'VT': 'R$ 553.369.097',
#  '_id': ObjectId('5c7185f8a887625d640ee04c')}
# {'ID': '75',
#  'NOME': 'Time New Bank',
#  'PRECO_BTC': 'BTC 0.00001693',
#  'PRECO_RS': 'R$ 0,47',
#  'VARIACAO': '657,14 %',
#  'VM': 'R$ 1.105.668.795',
#  'VT': 'R$ 11.880.438',
#  '_id': ObjectId('5c7185f8a887625d640ee04d')}
# {'ID': '22',
#  'NOME': 'Waves',
#  'PRECO_BTC': 'BTC 0.00070569',
#  'PRECO_RS': 'R$ 10,69',
#  'VARIACAO': '-1,05 %',
#  'VM': 'R$ 1.069.443.976',
#  'VT': 'R$ 44.621.933',
#  '_id': ObjectId('5c7185f8a887625d640ee04e')}
# {'ID': '76',
#  'NOME': 'DeepBrain Chain',
#  'PRECO_BTC': 'BTC 0.00002531',
#  'PRECO_RS': 'R$ 0,70',
#  'VARIACAO': '728,09 %',
#  'VM': 'R$ 1.050.101.003',
#  'VT': 'R$ 6.407.629',
#  '_id': ObjectId('5c7185f8a887625d640ee04f')}
# {'ID': '23',
#  'NOME': 'Tezos',
#  'PRECO_BTC': 'BTC 0.00011002',
#  'PRECO_RS': 'R$ 1,67',
#  'VARIACAO': '-0,19 %',
#  'VM': 'R$ 1.012.857.535',
#  'VT': 'R$ 14.860.782',
#  '_id': ObjectId('5c7185f8a887625d640ee050')}
# {'ID': '24',
#  'NOME': 'VeChain',
#  'PRECO_BTC': 'BTC 0.00000119',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '-0,92 %',
#  'VM': 'R$ 1.001.571.502',
#  'VT': 'R$ 47.573.297',
#  '_id': ObjectId('5c7185f8a887625d640ee051')}
# {'ID': '25',
#  'NOME': 'Dogecoin',
#  'PRECO_BTC': 'BTC 0.00000051',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '0,09 %',
#  'VM': 'R$ 913.898.185',
#  'VT': 'R$ 69.785.611',
#  '_id': ObjectId('5c7185f8a887625d640ee052')}
# {'ID': '84',
#  'NOME': 'Jibrel Network',
#  'PRECO_BTC': 'BTC 0.00020113',
#  'PRECO_RS': 'R$ 5,56',
#  'VARIACAO': '972,45 %',
#  'VM': 'R$ 890.161.994',
#  'VT': 'R$ 3.749.321',
#  '_id': ObjectId('5c7185f8a887625d640ee053')}
# {'ID': '26',
#  'NOME': 'USD Coin',
#  'PRECO_BTC': 'BTC 0.00025481',
#  'PRECO_RS': 'R$ 3,86',
#  'VARIACAO': '1,67 %',
#  'VM': 'R$ 889.083.033',
#  'VT': 'R$ 117.668.917',
#  '_id': ObjectId('5c7185f8a887625d640ee054')}
# {'ID': '27',
#  'NOME': 'Bitcoin Gold',
#  'PRECO_BTC': 'BTC 0.00326337',
#  'PRECO_RS': 'R$ 49,46',
#  'VARIACAO': '4,21 %',
#  'VM': 'R$ 861.212.055',
#  'VT': 'R$ 38.189.883',
#  '_id': ObjectId('5c7185f8a887625d640ee055')}
# {'ID': '86',
#  'NOME': 'eosDAC',
#  'PRECO_BTC': 'BTC 0.00004637',
#  'PRECO_RS': 'R$ 1,28',
#  'VARIACAO': '894,75 %',
#  'VM': 'R$ 847.537.591',
#  'VT': 'R$ 6.164.439',
#  '_id': ObjectId('5c7185f8a887625d640ee056')}
# {'ID': '88',
#  'NOME': 'iExec RLC',
#  'PRECO_BTC': 'BTC 0.00038118',
#  'PRECO_RS': 'R$ 10,54',
#  'VARIACAO': '505,54 %',
#  'VM': 'R$ 844.261.135',
#  'VT': 'R$ 3.417.860',
#  '_id': ObjectId('5c7185f8a887625d640ee057')}
# {'ID': '91',
#  'NOME': 'Mobius',
#  'PRECO_BTC': 'BTC 0.00007759',
#  'PRECO_RS': 'R$ 2,15',
#  'VARIACAO': '870,65 %',
#  'VM': 'R$ 808.432.903',
#  'VT': 'R$ 5.038.211',
#  '_id': ObjectId('5c7185f8a887625d640ee058')}
# {'ID': '92',
#  'NOME': 'Quantum Resistant Ledger',
#  'PRECO_BTC': 'BTC 0.00056026',
#  'PRECO_RS': 'R$ 15,50',
#  'VARIACAO': '818,93 %',
#  'VM': 'R$ 805.871.185',
#  'VT': 'R$ 1.674.009',
#  '_id': ObjectId('5c7185f8a887625d640ee059')}
# {'ID': '93',
#  'NOME': 'SONM',
#  'PRECO_BTC': 'BTC 0.00008004',
#  'PRECO_RS': 'R$ 2,21',
#  'VARIACAO': '554,95 %',
#  'VM': 'R$ 796.105.778',
#  'VT': 'R$ 3.672.679',
#  '_id': ObjectId('5c7185f8a887625d640ee05a')}
# {'ID': '95',
#  'NOME': 'Eidoo',
#  'PRECO_BTC': 'BTC 0.00096440',
#  'PRECO_RS': 'R$ 26,68',
#  'VARIACAO': '800,58 %',
#  'VM': 'R$ 780.593.108',
#  'VT': 'R$ 4.219.230',
#  '_id': ObjectId('5c7185f8a887625d640ee05b')}
# {'ID': '28',
#  'NOME': 'Qtum',
#  'PRECO_BTC': 'BTC 0.00057520',
#  'PRECO_RS': 'R$ 8,72',
#  'VARIACAO': '9,18 %',
#  'VM': 'R$ 778.231.298',
#  'VT': 'R$ 1.438.209.325',
#  '_id': ObjectId('5c7185f8a887625d640ee05c')}
# {'ID': '96',
#  'NOME': 'United Traders Token',
#  'PRECO_BTC': 'BTC 0.00075130',
#  'PRECO_RS': 'R$ 20,78',
#  'VARIACAO': '890,63 %',
#  'VM': 'R$ 776.029.306',
#  'VT': 'R$ 415.912',
#  '_id': ObjectId('5c7185f8a887625d640ee05d')}
# {'ID': '97',
#  'NOME': 'Primecoin',
#  'PRECO_BTC': 'BTC 0.00114420',
#  'PRECO_RS': 'R$ 31,65',
#  'VARIACAO': '692,99 %',
#  'VM': 'R$ 774.343.728',
#  'VT': 'R$ 3.296.645',
#  '_id': ObjectId('5c7185f8a887625d640ee05e')}
# {'ID': '29',
#  'NOME': 'TrueUSD',
#  'PRECO_BTC': 'BTC 0.00024897',
#  'PRECO_RS': 'R$ 3,77',
#  'VARIACAO': '-0,81 %',
#  'VM': 'R$ 773.232.116',
#  'VT': 'R$ 177.600.811',
#  '_id': ObjectId('5c7185f8a887625d640ee05f')}
# {'ID': '98',
#  'NOME': 'Genaro Network',
#  'PRECO_BTC': 'BTC 0.00008705',
#  'PRECO_RS': 'R$ 2,41',
#  'VARIACAO': '630,01 %',
#  'VM': 'R$ 767.877.968',
#  'VT': 'R$ 3.692.811',
#  '_id': ObjectId('5c7185f8a887625d640ee060')}
# {'ID': '100',
#  'NOME': 'Achain',
#  'PRECO_BTC': 'BTC 0.00004460',
#  'PRECO_RS': 'R$ 1,56',
#  'VARIACAO': '20,50 %',
#  'VM': 'R$ 746.032.631',
#  'VT': 'R$ 278.291.031',
#  '_id': ObjectId('5c7185f8a887625d640ee061')}
# {'ID': '30',
#  'NOME': 'OmiseGO',
#  'PRECO_BTC': 'BTC 0.00032756',
#  'PRECO_RS': 'R$ 4,96',
#  'VARIACAO': '1,42 %',
#  'VM': 'R$ 696.182.697',
#  'VT': 'R$ 150.230.032',
#  '_id': ObjectId('5c7185f8a887625d640ee062')}
# {'ID': '100',
#  'NOME': 'Request Network',
#  'PRECO_BTC': 'BTC 0.00003143',
#  'PRECO_RS': 'R$ 1,03',
#  'VARIACAO': '5,65 %',
#  'VM': 'R$ 685.623.931',
#  'VT': 'R$ 21.759.067',
#  '_id': ObjectId('5c7185f8a887625d640ee063')}
# {'ID': '31',
#  'NOME': 'Holo',
#  'PRECO_BTC': 'BTC 0.00000034',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '-0,99 %',
#  'VM': 'R$ 681.949.624',
#  'VT': 'R$ 41.607.830',
#  '_id': ObjectId('5c7185f8a887625d640ee064')}
# {'ID': '100',
#  'NOME': 'Nucleus Vision',
#  'PRECO_BTC': 'BTC 0.00000482',
#  'PRECO_RS': 'R$ 0,16',
#  'VARIACAO': '-1,75 %',
#  'VM': 'R$ 677.921.158',
#  'VT': 'R$ 96.326.935',
#  '_id': ObjectId('5c7185f8a887625d640ee065')}
# {'ID': '82',
#  'NOME': 'Credits',
#  'PRECO_BTC': 'BTC 0.00017612',
#  'PRECO_RS': 'R$ 4,88',
#  'VARIACAO': '451,16 %',
#  'VM': 'R$ 675.677.545',
#  'VT': 'R$ 7.630.176',
#  '_id': ObjectId('5c7185f8a887625d640ee066')}
# {'ID': '76',
#  'NOME': 'Game.com',
#  'PRECO_BTC': 'BTC 0.00003194',
#  'PRECO_RS': 'R$ 0,88',
#  'VARIACAO': '250,27 %',
#  'VM': 'R$ 673.129.111',
#  'VT': 'R$ 50.316.537',
#  '_id': ObjectId('5c7185f8a887625d640ee067')}
# {'ID': '32',
#  'NOME': 'Basic Attention Token',
#  'PRECO_BTC': 'BTC 0.00003470',
#  'PRECO_RS': 'R$ 0,53',
#  'VARIACAO': '3,03 %',
#  'VM': 'R$ 651.582.223',
#  'VT': 'R$ 20.772.529',
#  '_id': ObjectId('5c7185f8a887625d640ee068')}
# {'ID': '33',
#  'NOME': 'Paragon',
#  'PRECO_BTC': 'BTC 0.00066454',
#  'PRECO_RS': 'R$ 9,72',
#  'VARIACAO': '1.413,44 %',
#  'VM': 'R$ 640.981.879',
#  'VT': 'R$ 11.557.232',
#  '_id': ObjectId('5c7185f8a887625d640ee069')}
# {'ID': '93',
#  'NOME': 'Neblio',
#  'PRECO_BTC': 'BTC 0.00161525',
#  'PRECO_RS': 'R$ 48,07',
#  'VARIACAO': '10,79 %',
#  'VM': 'R$ 629.984.210',
#  'VT': 'R$ 35.988.570',
#  '_id': ObjectId('5c7185f8a887625d640ee06a')}
# {'ID': '33',
#  'NOME': 'Decred',
#  'PRECO_BTC': 'BTC 0.00434876',
#  'PRECO_RS': 'R$ 66,03',
#  'VARIACAO': '3,27 %',
#  'VM': 'R$ 618.291.615',
#  'VT': 'R$ 4.645.551',
#  '_id': ObjectId('5c7185f8a887625d640ee06b')}
# {'ID': '34',
#  'NOME': 'Chainlink',
#  'PRECO_BTC': 'BTC 0.00011370',
#  'PRECO_RS': 'R$ 1,72',
#  'VARIACAO': '1,87 %',
#  'VM': 'R$ 603.082.463',
#  'VT': 'R$ 13.449.209',
#  '_id': ObjectId('5c7185f8a887625d640ee06c')}
# {'ID': '69',
#  'NOME': 'ERC20',
#  'PRECO_BTC': 'BTC 0.00001574',
#  'PRECO_RS': 'R$ 0,38',
#  'VARIACAO': '2.221,52 %',
#  'VM': 'R$ 600.544.378',
#  'VT': 'R$ 2.368',
#  '_id': ObjectId('5c7185f8a887625d640ee06d')}
# {'ID': '77',
#  'NOME': 'SmartMesh',
#  'PRECO_BTC': 'BTC 0.00001534',
#  'PRECO_RS': 'R$ 0,42',
#  'VARIACAO': '317,07 %',
#  'VM': 'R$ 600.240.619',
#  'VT': 'R$ 5.751.042',
#  '_id': ObjectId('5c7185f8a887625d640ee06e')}
# {'ID': '35',
#  'NOME': 'Zilliqa',
#  'PRECO_BTC': 'BTC 0.00000478',
#  'PRECO_RS': 'R$ 0,07',
#  'VARIACAO': '5,14 %',
#  'VM': 'R$ 599.867.178',
#  'VT': 'R$ 43.419.110',
#  '_id': ObjectId('5c7185f8a887625d640ee06f')}
# {'ID': '99',
#  'NOME': 'DATA',
#  'PRECO_BTC': 'BTC 0.00000468',
#  'PRECO_RS': 'R$ 0,13',
#  'VARIACAO': '787,97 %',
#  'VM': 'R$ 599.336.786',
#  'VT': 'R$ 20.873.767',
#  '_id': ObjectId('5c7185f8a887625d640ee070')}
# {'ID': '79',
#  'NOME': 'MediShares',
#  'PRECO_BTC': 'BTC 0.00002092',
#  'PRECO_RS': 'R$ 0,58',
#  'VARIACAO': '393,13 %',
#  'VM': 'R$ 597.289.533',
#  'VT': 'R$ 8.882.535',
#  '_id': ObjectId('5c7185f8a887625d640ee071')}
# {'ID': '100',
#  'NOME': 'Delphy',
#  'PRECO_BTC': 'BTC 0.00049122',
#  'PRECO_RS': 'R$ 13,59',
#  'VARIACAO': '808,90 %',
#  'VM': 'R$ 596.917.115',
#  'VT': 'R$ 19.059.095',
#  '_id': ObjectId('5c7185f8a887625d640ee072')}
# {'ID': '100',
#  'NOME': 'Matrix AI Network',
#  'PRECO_BTC': 'BTC 0.00012774',
#  'PRECO_RS': 'R$ 3,97',
#  'VARIACAO': '-4,22 %',
#  'VM': 'R$ 595.651.964',
#  'VT': 'R$ 30.777.383',
#  '_id': ObjectId('5c7185f8a887625d640ee073')}
# {'ID': '36',
#  'NOME': 'Augur',
#  'PRECO_BTC': 'BTC 0.00349744',
#  'PRECO_RS': 'R$ 53,10',
#  'VARIACAO': '2,17 %',
#  'VM': 'R$ 584.107.391',
#  'VT': 'R$ 9.691.382',
#  '_id': ObjectId('5c7185f8a887625d640ee074')}
# {'ID': '83',
#  'NOME': 'Tokenomy',
#  'PRECO_BTC': 'BTC 0.00014451',
#  'PRECO_RS': 'R$ 4,00',
#  'VARIACAO': '426,75 %',
#  'VM': 'R$ 584.018.317',
#  'VT': 'R$ 9.951.646',
#  '_id': ObjectId('5c7185f8a887625d640ee075')}
# {'ID': '100',
#  'NOME': 'TokenPay',
#  'PRECO_BTC': 'BTC 0.00121885',
#  'PRECO_RS': 'R$ 37,11',
#  'VARIACAO': '22,54 %',
#  'VM': 'R$ 567.697.812',
#  'VT': 'R$ 8.116.163',
#  '_id': ObjectId('5c7185f8a887625d640ee076')}
# {'ID': '97',
#  'NOME': 'MyBit Token',
#  'PRECO_BTC': 'BTC 0.00037796',
#  'PRECO_RS': 'R$ 10,98',
#  'VARIACAO': '-2,35 %',
#  'VM': 'R$ 566.547.859',
#  'VT': 'R$ 1.990.228',
#  '_id': ObjectId('5c7185f8a887625d640ee077')}
# {'ID': '99',
#  'NOME': 'NavCoin',
#  'PRECO_BTC': 'BTC 0.00031080',
#  'PRECO_RS': 'R$ 8,94',
#  'VARIACAO': '101,85 %',
#  'VM': 'R$ 561.058.964',
#  'VT': 'R$ 8.392.600',
#  '_id': ObjectId('5c7185f8a887625d640ee078')}
# {'ID': '37',
#  'NOME': 'Lisk',
#  'PRECO_BTC': 'BTC 0.00031748',
#  'PRECO_RS': 'R$ 4,82',
#  'VARIACAO': '1,26 %',
#  'VM': 'R$ 553.602.563',
#  'VT': 'R$ 15.212.018',
#  '_id': ObjectId('5c7185f8a887625d640ee079')}
# {'ID': '38',
#  'NOME': '0x',
#  'PRECO_BTC': 'BTC 0.00006249',
#  'PRECO_RS': 'R$ 0,95',
#  'VARIACAO': '1,10 %',
#  'VM': 'R$ 553.362.786',
#  'VT': 'R$ 33.259.755',
#  '_id': ObjectId('5c7185f8a887625d640ee07a')}
# {'ID': '84',
#  'NOME': 'Ruff',
#  'PRECO_BTC': 'BTC 0.00002162',
#  'PRECO_RS': 'R$ 0,60',
#  'VARIACAO': '356,20 %',
#  'VM': 'R$ 552.791.599',
#  'VT': 'R$ 31.536.256',
#  '_id': ObjectId('5c7185f8a887625d640ee07b')}
# {'ID': '100',
#  'NOME': 'Storiqa',
#  'PRECO_BTC': 'BTC 0.00000238',
#  'PRECO_RS': 'R$ 0,07',
#  'VARIACAO': '121,54 %',
#  'VM': 'R$ 519.472.363',
#  'VT': 'R$ 305.319.501',
#  '_id': ObjectId('5c7185f8a887625d640ee07c')}
# {'ID': '89',
#  'NOME': 'Cube',
#  'PRECO_BTC': 'BTC 0.00000277',
#  'PRECO_RS': 'R$ 0,08',
#  'VARIACAO': '238,72 %',
#  'VM': 'R$ 519.234.382',
#  'VT': 'R$ 3.600.899',
#  '_id': ObjectId('5c7185f8a887625d640ee07d')}
# {'ID': '84',
#  'NOME': 'Litecoin Cash',
#  'PRECO_BTC': 'BTC 0.00003596',
#  'PRECO_RS': 'R$ 0,91',
#  'VARIACAO': '269,92 %',
#  'VM': 'R$ 519.148.400',
#  'VT': 'R$ 843.307',
#  '_id': ObjectId('5c7185f8a887625d640ee07e')}
# {'ID': '90',
#  'NOME': 'Scry.info',
#  'PRECO_BTC': 'BTC 0.00004247',
#  'PRECO_RS': 'R$ 1,18',
#  'VARIACAO': '144,19 %',
#  'VM': 'R$ 517.336.997',
#  'VT': 'R$ 2.545.768',
#  '_id': ObjectId('5c7185f8a887625d640ee07f')}
# {'ID': '69',
#  'NOME': 'CyberVein',
#  'PRECO_BTC': 'BTC 0.00001773',
#  'PRECO_RS': 'R$ 0,49',
#  'VARIACAO': '151,34 %',
#  'VM': 'R$ 514.780.528',
#  'VT': 'R$ 3.271.771',
#  '_id': ObjectId('5c7185f8a887625d640ee080')}
# {'ID': '99',
#  'NOME': 'True Chain',
#  'PRECO_BTC': 'BTC 0.00040268',
#  'PRECO_RS': 'R$ 10,79',
#  'VARIACAO': '22,28 %',
#  'VM': 'R$ 501.029.920',
#  'VT': 'R$ 973.771.160',
#  '_id': ObjectId('5c7185f8a887625d640ee081')}
# {'ID': '99',
#  'NOME': 'The ChampCoin',
#  'PRECO_BTC': 'BTC 0.00011300',
#  'PRECO_RS': 'R$ 3,02',
#  'VARIACAO': '1.520,22 %',
#  'VM': 'R$ 497.955.788',
#  'VT': 'R$ 22.551',
#  '_id': ObjectId('5c7185f8a887625d640ee082')}
# {'ID': '39',
#  'NOME': 'BitShares',
#  'PRECO_BTC': 'BTC 0.00001217',
#  'PRECO_RS': 'R$ 0,18',
#  'VARIACAO': '7,35 %',
#  'VM': 'R$ 497.553.770',
#  'VT': 'R$ 33.620.241',
#  '_id': ObjectId('5c7185f8a887625d640ee083')}
# {'ID': '40',
#  'NOME': 'Bytecoin',
#  'PRECO_BTC': 'BTC 0.00000018',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '3,56 %',
#  'VM': 'R$ 491.438.347',
#  'VT': 'R$ 510.288',
#  '_id': ObjectId('5c7185f8a887625d640ee084')}
# {'ID': '41',
#  'NOME': 'ICON',
#  'PRECO_BTC': 'BTC 0.00006577',
#  'PRECO_RS': 'R$ 1,00',
#  'VARIACAO': '7,44 %',
#  'VM': 'R$ 471.825.851',
#  'VT': 'R$ 36.583.085',
#  '_id': ObjectId('5c7185f8a887625d640ee085')}
# {'ID': '42',
#  'NOME': 'Nano',
#  'PRECO_BTC': 'BTC 0.00023056',
#  'PRECO_RS': 'R$ 3,50',
#  'VARIACAO': '2,31 %',
#  'VM': 'R$ 466.449.388',
#  'VT': 'R$ 5.777.582',
#  '_id': ObjectId('5c7185f8a887625d640ee086')}
# {'ID': '43',
#  'NOME': 'DigiByte',
#  'PRECO_BTC': 'BTC 0.00000267',
#  'PRECO_RS': 'R$ 0,04',
#  'VARIACAO': '5,96 %',
#  'VM': 'R$ 465.167.326',
#  'VT': 'R$ 7.271.564',
#  '_id': ObjectId('5c7185f8a887625d640ee087')}
# {'ID': '44',
#  'NOME': 'Bitcoin Diamond',
#  'PRECO_BTC': 'BTC 0.00019431',
#  'PRECO_RS': 'R$ 2,94',
#  'VARIACAO': '2,80 %',
#  'VM': 'R$ 452.765.082',
#  'VT': 'R$ 6.663.804',
#  '_id': ObjectId('5c7185f8a887625d640ee088')}
# {'ID': '45',
#  'NOME': 'Pundi X',
#  'PRECO_BTC': 'BTC 0.00000017',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '-0,92 %',
#  'VM': 'R$ 441.381.676',
#  'VT': 'R$ 4.746.446',
#  '_id': ObjectId('5c7185f8a887625d640ee089')}
# {'ID': '44',
#  'NOME': 'Nasdacoin',
#  'PRECO_BTC': 'BTC 0.00151945',
#  'PRECO_RS': 'R$ 23,10',
#  'VARIACAO': '813,05 %',
#  'VM': 'R$ 439.480.975',
#  'VT': 'R$ 1.266.559',
#  '_id': ObjectId('5c7185f8a887625d640ee08a')}
# {'ID': '46',
#  'NOME': 'Paxos Standard Token',
#  'PRECO_BTC': 'BTC 0.00024948',
#  'PRECO_RS': 'R$ 3,78',
#  'VARIACAO': '-0,67 %',
#  'VM': 'R$ 436.701.153',
#  'VT': 'R$ 263.411.280',
#  '_id': ObjectId('5c7185f8a887625d640ee08b')}
# {'ID': '44',
#  'NOME': 'ETERNAL TOKEN',
#  'PRECO_BTC': 'BTC 0.00041855',
#  'PRECO_RS': 'R$ 6,38',
#  'VARIACAO': '148,15 %',
#  'VM': 'R$ 433.342.730',
#  'VT': 'R$ 1.634.866',
#  '_id': ObjectId('5c7185f8a887625d640ee08c')}
# {'ID': '71',
#  'NOME': 'Vulcano',
#  'PRECO_BTC': 'BTC 0.00000180',
#  'PRECO_RS': 'R$ 0,05',
#  'VARIACAO': '472,60 %',
#  'VM': 'R$ 416.142.118',
#  'VT': 'R$ 13.115',
#  '_id': ObjectId('5c7185f8a887625d640ee08d')}
# {'ID': '47',
#  'NOME': 'Aeternity',
#  'PRECO_BTC': 'BTC 0.00011420',
#  'PRECO_RS': 'R$ 1,73',
#  'VARIACAO': '5,94 %',
#  'VM': 'R$ 404.035.864',
#  'VT': 'R$ 209.975.862',
#  '_id': ObjectId('5c7185f8a887625d640ee08e')}
# {'ID': '48',
#  'NOME': 'Steem',
#  'PRECO_BTC': 'BTC 0.00008483',
#  'PRECO_RS': 'R$ 1,29',
#  'VARIACAO': '3,25 %',
#  'VM': 'R$ 403.916.880',
#  'VT': 'R$ 5.688.568',
#  '_id': ObjectId('5c7185f8a887625d640ee08f')}
# {'ID': '49',
#  'NOME': 'Komodo',
#  'PRECO_BTC': 'BTC 0.00023450',
#  'PRECO_RS': 'R$ 3,56',
#  'VARIACAO': '0,86 %',
#  'VM': 'R$ 398.184.570',
#  'VT': 'R$ 5.045.321',
#  '_id': ObjectId('5c7185f8a887625d640ee090')}
# {'ID': '64',
#  'NOME': 'Hshare',
#  'PRECO_BTC': 'BTC 0.00034814',
#  'PRECO_RS': 'R$ 9,12',
#  'VARIACAO': '-30,01 %',
#  'VM': 'R$ 397.068.914',
#  'VT': 'R$ 29.167.170',
#  '_id': ObjectId('5c7185f8a887625d640ee091')}
# {'ID': '72',
#  'NOME': 'AurumCoin',
#  'PRECO_BTC': 'BTC 0.04589363',
#  'PRECO_RS': 'R$ 1.315,33',
#  'VARIACAO': '743,32 %',
#  'VM': 'R$ 391.965.402',
#  'VT': 'R$ 94.062',
#  '_id': ObjectId('5c7185f8a887625d640ee092')}
# {'ID': '50',
#  'NOME': 'Siacoin',
#  'PRECO_BTC': 'BTC 0.00000063',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '-0,67 %',
#  'VM': 'R$ 379.432.025',
#  'VT': 'R$ 6.101.895',
#  '_id': ObjectId('5c7185f8a887625d640ee093')}
# {'ID': '51',
#  'NOME': 'Bytom',
#  'PRECO_BTC': 'BTC 0.00002467',
#  'PRECO_RS': 'R$ 0,37',
#  'VARIACAO': '6,94 %',
#  'VM': 'R$ 375.458.081',
#  'VT': 'R$ 41.148.692',
#  '_id': ObjectId('5c7185f8a887625d640ee094')}
# {'ID': '52',
#  'NOME': 'Verge',
#  'PRECO_BTC': 'BTC 0.00000161',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '0,61 %',
#  'VM': 'R$ 371.816.223',
#  'VT': 'R$ 3.240.063',
#  '_id': ObjectId('5c7185f8a887625d640ee095')}
# {'ID': '100',
#  'NOME': 'All Sports',
#  'PRECO_BTC': 'BTC 0.00001850',
#  'PRECO_RS': 'R$ 0,45',
#  'VARIACAO': '-2,92 %',
#  'VM': 'R$ 369.194.021',
#  'VT': 'R$ 62.966.983',
#  '_id': ObjectId('5c7185f8a887625d640ee096')}
# {'ID': '53',
#  'NOME': 'IOST',
#  'PRECO_BTC': 'BTC 0.00000202',
#  'PRECO_RS': 'R$ 0,03',
#  'VARIACAO': '-0,61 %',
#  'VM': 'R$ 366.981.010',
#  'VT': 'R$ 30.515.965',
#  '_id': ObjectId('5c7185f8a887625d640ee097')}
# {'ID': '100',
#  'NOME': 'Skycoin',
#  'PRECO_BTC': 'BTC 0.00166314',
#  'PRECO_RS': 'R$ 40,68',
#  'VARIACAO': '-3,50 %',
#  'VM': 'R$ 366.094.128',
#  'VT': 'R$ 6.966.849',
#  '_id': ObjectId('5c7185f8a887625d640ee098')}
# {'ID': '100',
#  'NOME': 'Storm',
#  'PRECO_BTC': 'BTC 0.00000318',
#  'PRECO_RS': 'R$ 0,08',
#  'VARIACAO': '7,22 %',
#  'VM': 'R$ 366.024.850',
#  'VT': 'R$ 89.266.938',
#  '_id': ObjectId('5c7185f8a887625d640ee099')}
# {'ID': '97',
#  'NOME': 'Civic',
#  'PRECO_BTC': 'BTC 0.00003806',
#  'PRECO_RS': 'R$ 1,06',
#  'VARIACAO': '37,74 %',
#  'VM': 'R$ 362.131.654',
#  'VT': 'R$ 77.890.996',
#  '_id': ObjectId('5c7185f8a887625d640ee09a')}
# {'ID': '63',
#  'NOME': 'Ripio Credit Network',
#  'PRECO_BTC': 'BTC 0.00003377',
#  'PRECO_RS': 'R$ 0,72',
#  'VARIACAO': '534,24 %',
#  'VM': 'R$ 358.685.284',
#  'VT': 'R$ 4.907.158',
#  '_id': ObjectId('5c7185f8a887625d640ee09b')}
# {'ID': '98',
#  'NOME': 'Ethos',
#  'PRECO_BTC': 'BTC 0.00015591',
#  'PRECO_RS': 'R$ 4,56',
#  'VARIACAO': '-3,18 %',
#  'VM': 'R$ 353.022.699',
#  'VT': 'R$ 7.143.600',
#  '_id': ObjectId('5c7185f8a887625d640ee09c')}
# {'ID': '73',
#  'NOME': 'Stakenet',
#  'PRECO_BTC': 'BTC 0.00018340',
#  'PRECO_RS': 'R$ 4,97',
#  'VARIACAO': '376,11 %',
#  'VM': 'R$ 351.926.406',
#  'VT': 'R$ 482.916',
#  '_id': ObjectId('5c7185f8a887625d640ee09d')}
# {'ID': '70',
#  'NOME': 'NAGA',
#  'PRECO_BTC': 'BTC 0.00023272',
#  'PRECO_RS': 'R$ 5,90',
#  'VARIACAO': '425,76 %',
#  'VM': 'R$ 347.127.441',
#  'VT': 'R$ 209.360',
#  '_id': ObjectId('5c7185f8a887625d640ee09e')}
# {'ID': '54',
#  'NOME': 'Stratis',
#  'PRECO_BTC': 'BTC 0.00022881',
#  'PRECO_RS': 'R$ 3,47',
#  'VARIACAO': '0,47 %',
#  'VM': 'R$ 344.697.930',
#  'VT': 'R$ 5.362.710',
#  '_id': ObjectId('5c7185f8a887625d640ee09f')}
# {'ID': '100',
#  'NOME': 'Gifto',
#  'PRECO_BTC': 'BTC 0.00002264',
#  'PRECO_RS': 'R$ 0,63',
#  'VARIACAO': '-0,96 %',
#  'VM': 'R$ 338.354.843',
#  'VT': 'R$ 213.417.447',
#  '_id': ObjectId('5c7185f8a887625d640ee0a0')}
# {'ID': '80',
#  'NOME': 'Envion',
#  'PRECO_BTC': 'BTC 0.00010982',
#  'PRECO_RS': 'R$ 3,03',
#  'VARIACAO': '1.089,98 %',
#  'VM': 'R$ 337.163.475',
#  'VT': 'R$ 7.515',
#  '_id': ObjectId('5c7185f8a887625d640ee0a1')}
# {'ID': '100',
#  'NOME': 'Fusion',
#  'PRECO_BTC': 'BTC 0.00045752',
#  'PRECO_RS': 'R$ 11,30',
#  'VARIACAO': '-8,58 %',
#  'VM': 'R$ 335.480.992',
#  'VT': 'R$ 16.815.276',
#  '_id': ObjectId('5c7185f8a887625d640ee0a2')}
# {'ID': '98',
#  'NOME': 'Jiyo',
#  'PRECO_BTC': 'BTC 0.00033500',
#  'PRECO_RS': 'R$ 8,05',
#  'VARIACAO': '5.128,52 %',
#  'VM': 'R$ 330.860.213',
#  'VT': 'R$ 275.192',
#  '_id': ObjectId('5c7185f8a887625d640ee0a3')}
# {'ID': '55',
#  'NOME': 'Dai',
#  'PRECO_BTC': 'BTC 0.00025562',
#  'PRECO_RS': 'R$ 3,87',
#  'VARIACAO': '2,42 %',
#  'VM': 'R$ 323.828.221',
#  'VT': 'R$ 140.082.271',
#  '_id': ObjectId('5c7185f8a887625d640ee0a4')}
# {'ID': '56',
#  'NOME': 'THETA',
#  'PRECO_BTC': 'BTC 0.00002412',
#  'PRECO_RS': 'R$ 0,37',
#  'VARIACAO': '0,49 %',
#  'VM': 'R$ 318.238.684',
#  'VT': 'R$ 8.127.603',
#  '_id': ObjectId('5c7185f8a887625d640ee0a5')}
# {'ID': '100',
#  'NOME': 'KickCoin',
#  'PRECO_BTC': 'BTC 0.00002076',
#  'PRECO_RS': 'R$ 0,59',
#  'VARIACAO': '5,73 %',
#  'VM': 'R$ 307.436.018',
#  'VT': 'R$ 41.110.759',
#  '_id': ObjectId('5c7185f8a887625d640ee0a6')}
# {'ID': '83',
#  'NOME': 'Ignis',
#  'PRECO_BTC': 'BTC 0.00001447',
#  'PRECO_RS': 'R$ 0,40',
#  'VARIACAO': '100,56 %',
#  'VM': 'R$ 302.680.897',
#  'VT': 'R$ 1.014.261',
#  '_id': ObjectId('5c7185f8a887625d640ee0a7')}
# {'ID': '100',
#  'NOME': 'Docademic',
#  'PRECO_BTC': 'BTC 0.00004441',
#  'PRECO_RS': 'R$ 1,04',
#  'VARIACAO': '-0,65 %',
#  'VM': 'R$ 301.813.857',
#  'VT': 'R$ 2.015.411',
#  '_id': ObjectId('5c7185f8a887625d640ee0a8')}
# {'ID': '75',
#  'NOME': 'Dragonchain',
#  'PRECO_BTC': 'BTC 0.00005395',
#  'PRECO_RS': 'R$ 1,26',
#  'VARIACAO': '60,49 %',
#  'VM': 'R$ 299.970.987',
#  'VT': 'R$ 4.187.486',
#  '_id': ObjectId('5c7185f8a887625d640ee0a9')}
# {'ID': '57',
#  'NOME': 'Status',
#  'PRECO_BTC': 'BTC 0.00000551',
#  'PRECO_RS': 'R$ 0,08',
#  'VARIACAO': '0,79 %',
#  'VM': 'R$ 289.867.421',
#  'VT': 'R$ 71.981.654',
#  '_id': ObjectId('5c7185f8a887625d640ee0aa')}
# {'ID': '58',
#  'NOME': 'Gemini Dollar',
#  'PRECO_BTC': 'BTC 0.00024946',
#  'PRECO_RS': 'R$ 3,78',
#  'VARIACAO': '-0,27 %',
#  'VM': 'R$ 286.189.588',
#  'VT': 'R$ 17.878.551',
#  '_id': ObjectId('5c7185f8a887625d640ee0ab')}
# {'ID': '59',
#  'NOME': 'REPO',
#  'PRECO_BTC': 'BTC 0.00017102',
#  'PRECO_RS': 'R$ 2,59',
#  'VARIACAO': '2,21 %',
#  'VM': 'R$ 284.985.231',
#  'VT': 'R$ 188.405',
#  '_id': ObjectId('5c7185f8a887625d640ee0ac')}
# {'ID': '60',
#  'NOME': 'Mixin',
#  'PRECO_BTC': 'BTC 0.03961136',
#  'PRECO_RS': 'R$ 600,30',
#  'VARIACAO': '3,76 %',
#  'VM': 'R$ 280.512.039',
#  'VT': 'R$ 826.220',
#  '_id': ObjectId('5c7185f8a887625d640ee0ad')}
# {'ID': '100',
#  'NOME': 'Blocknet',
#  'PRECO_BTC': 'BTC 0.00241893',
#  'PRECO_RS': 'R$ 53,83',
#  'VARIACAO': '-5,84 %',
#  'VM': 'R$ 280.087.869',
#  'VT': 'R$ 213.056',
#  '_id': ObjectId('5c7185f8a887625d640ee0ae')}
# {'ID': '81',
#  'NOME': 'PumaPay',
#  'PRECO_BTC': 'BTC 0.00000067',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '297,96 %',
#  'VM': 'R$ 279.956.131',
#  'VT': 'R$ 31.723',
#  '_id': ObjectId('5c7185f8a887625d640ee0af')}
# {'ID': '100',
#  'NOME': 'Byteball Bytes',
#  'PRECO_BTC': 'BTC 0.01447949',
#  'PRECO_RS': 'R$ 421,73',
#  'VARIACAO': '8,34 %',
#  'VM': 'R$ 279.524.972',
#  'VT': 'R$ 582.861',
#  '_id': ObjectId('5c7185f8a887625d640ee0b0')}
# {'ID': '99',
#  'NOME': 'Substratum',
#  'PRECO_BTC': 'BTC 0.00002517',
#  'PRECO_RS': 'R$ 0,73',
#  'VARIACAO': '4,35 %',
#  'VM': 'R$ 278.613.575',
#  'VT': 'R$ 8.537.692',
#  '_id': ObjectId('5c7185f8a887625d640ee0b1')}
# {'ID': '89',
#  'NOME': 'BnkToTheFuture',
#  'PRECO_BTC': 'BTC 0.00001668',
#  'PRECO_RS': 'R$ 0,43',
#  'VARIACAO': '178,56 %',
#  'VM': 'R$ 268.448.948',
#  'VT': 'R$ 1.310.724',
#  '_id': ObjectId('5c7185f8a887625d640ee0b2')}
# {'ID': '61',
#  'NOME': 'Populous',
#  'PRECO_BTC': 'BTC 0.00032850',
#  'PRECO_RS': 'R$ 4,99',
#  'VARIACAO': '2,37 %',
#  'VM': 'R$ 265.599.297',
#  'VT': 'R$ 4.662.357',
#  '_id': ObjectId('5c7185f8a887625d640ee0b3')}
# {'ID': '62',
#  'NOME': 'Ark',
#  'PRECO_BTC': 'BTC 0.00015651',
#  'PRECO_RS': 'R$ 2,38',
#  'VARIACAO': '-0,22 %',
#  'VM': 'R$ 257.934.664',
#  'VT': 'R$ 4.330.618',
#  '_id': ObjectId('5c7185f8a887625d640ee0b4')}
# {'ID': '94',
#  'NOME': 'WaykiChain',
#  'PRECO_BTC': 'BTC 0.00005531',
#  'PRECO_RS': 'R$ 1,45',
#  'VARIACAO': '65,96 %',
#  'VM': 'R$ 254.357.587',
#  'VT': 'R$ 3.050.608',
#  '_id': ObjectId('5c7185f8a887625d640ee0b5')}
# {'ID': '98',
#  'NOME': 'TaTaTu',
#  'PRECO_BTC': 'BTC 0.00009173',
#  'PRECO_RS': 'R$ 2,63',
#  'VARIACAO': '8,89 %',
#  'VM': 'R$ 254.063.536',
#  'VT': 'R$ 2.241.991',
#  '_id': ObjectId('5c7185f8a887625d640ee0b6')}
# {'ID': '63',
#  'NOME': 'Electroneum',
#  'PRECO_BTC': 'BTC 0.00000185',
#  'PRECO_RS': 'R$ 0,03',
#  'VARIACAO': '7,38 %',
#  'VM': 'R$ 251.840.191',
#  'VT': 'R$ 1.169.792',
#  '_id': ObjectId('5c7185f8a887625d640ee0b7')}
# {'ID': '88',
#  'NOME': 'Paypex',
#  'PRECO_BTC': 'BTC 0.00014574',
#  'PRECO_RS': 'R$ 3,68',
#  'VARIACAO': '154,83 %',
#  'VM': 'R$ 251.727.066',
#  'VT': 'R$ 162.282',
#  '_id': ObjectId('5c7185f8a887625d640ee0b8')}
# {'ID': '64',
#  'NOME': 'Revain',
#  'PRECO_BTC': 'BTC 0.00003425',
#  'PRECO_RS': 'R$ 0,52',
#  'VARIACAO': '-1,39 %',
#  'VM': 'R$ 251.433.015',
#  'VT': 'R$ 4.258.619',
#  '_id': ObjectId('5c7185f8a887625d640ee0b9')}
# {'ID': '65',
#  'NOME': 'Golem',
#  'PRECO_BTC': 'BTC 0.00001716',
#  'PRECO_RS': 'R$ 0,26',
#  'VARIACAO': '2,20 %',
#  'VM': 'R$ 251.013.791',
#  'VT': 'R$ 3.262.108',
#  '_id': ObjectId('5c7185f8a887625d640ee0ba')}
# {'ID': '98',
#  'NOME': 'Rivetz',
#  'PRECO_BTC': 'BTC 0.00036047',
#  'PRECO_RS': 'R$ 9,47',
#  'VARIACAO': '1.826,42 %',
#  'VM': 'R$ 248.437.048',
#  'VT': 'R$ 3.140',
#  '_id': ObjectId('5c7185f8a887625d640ee0bb')}
# {'ID': '97',
#  'NOME': 'Emercoin',
#  'PRECO_BTC': 'BTC 0.00024831',
#  'PRECO_RS': 'R$ 5,83',
#  'VARIACAO': '48,92 %',
#  'VM': 'R$ 245.484.289',
#  'VT': 'R$ 1.181.589',
#  '_id': ObjectId('5c7185f8a887625d640ee0bc')}
# {'ID': '66',
#  'NOME': 'Cryptonex',
#  'PRECO_BTC': 'BTC 0.00028832',
#  'PRECO_RS': 'R$ 4,37',
#  'VARIACAO': '2,25 %',
#  'VM': 'R$ 243.315.507',
#  'VT': 'R$ 22.656.602',
#  '_id': ObjectId('5c7185f8a887625d640ee0bd')}
# {'ID': '100',
#  'NOME': 'Genesis Vision',
#  'PRECO_BTC': 'BTC 0.00224604',
#  'PRECO_RS': 'R$ 53,88',
#  'VARIACAO': '-7,94 %',
#  'VM': 'R$ 238.005.189',
#  'VT': 'R$ 19.075.440',
#  '_id': ObjectId('5c7185f8a887625d640ee0be')}
# {'ID': '97',
#  'NOME': 'Spectre.ai Dividend Token',
#  'PRECO_BTC': 'BTC 0.00012296',
#  'PRECO_RS': 'R$ 2,88',
#  'VARIACAO': '129,75 %',
#  'VM': 'R$ 236.562.360',
#  'VT': 'R$ 133.610',
#  '_id': ObjectId('5c7185f8a887625d640ee0bf')}
# {'ID': '67',
#  'NOME': 'Huobi Token',
#  'PRECO_BTC': 'BTC 0.00030984',
#  'PRECO_RS': 'R$ 4,70',
#  'VARIACAO': '-0,47 %',
#  'VM': 'R$ 234.778.964',
#  'VT': 'R$ 42.559.895',
#  '_id': ObjectId('5c7185f8a887625d640ee0c0')}
# {'ID': '100',
#  'NOME': 'SALT',
#  'PRECO_BTC': 'BTC 0.00012056',
#  'PRECO_RS': 'R$ 2,84',
#  'VARIACAO': '12,85 %',
#  'VM': 'R$ 234.167.525',
#  'VT': 'R$ 10.855.332',
#  '_id': ObjectId('5c7185f8a887625d640ee0c1')}
# {'ID': '100',
#  'NOME': 'Kyber Network',
#  'PRECO_BTC': 'BTC 0.00007353',
#  'PRECO_RS': 'R$ 1,74',
#  'VARIACAO': '-6,26 %',
#  'VM': 'R$ 232.943.760',
#  'VT': 'R$ 69.785.555',
#  '_id': ObjectId('5c7185f8a887625d640ee0c2')}
# {'ID': '95',
#  'NOME': 'BitcoinDark',
#  'PRECO_BTC': 'BTC 0.00679895',
#  'PRECO_RS': 'R$ 179,21',
#  'VARIACAO': '17,63 %',
#  'VM': 'R$ 230.974.331',
#  'VT': 'R$ 1.453.208',
#  '_id': ObjectId('5c7185f8a887625d640ee0c3')}
# {'ID': '100',
#  'NOME': 'ZClassic',
#  'PRECO_BTC': 'BTC 0.00202587',
#  'PRECO_RS': 'R$ 50,08',
#  'VARIACAO': '-2,01 %',
#  'VM': 'R$ 230.225.347',
#  'VT': 'R$ 5.642.682',
#  '_id': ObjectId('5c7185f8a887625d640ee0c4')}
# {'ID': '68',
#  'NOME': 'S4FE',
#  'PRECO_BTC': 'BTC 0.00043451',
#  'PRECO_RS': 'R$ 6,58',
#  'VARIACAO': '107,87 %',
#  'VM': 'R$ 229.080.935',
#  'VT': 'R$ 3.165.089',
#  '_id': ObjectId('5c7185f8a887625d640ee0c5')}
# {'ID': '92',
#  'NOME': 'APIS',
#  'PRECO_BTC': 'BTC 0.00000174',
#  'PRECO_RS': 'R$ 0,05',
#  'VARIACAO': '101,81 %',
#  'VM': 'R$ 226.581.589',
#  'VT': 'R$ 31.761.657',
#  '_id': ObjectId('5c7185f8a887625d640ee0c6')}
# {'ID': '69',
#  'NOME': 'Ardor',
#  'PRECO_BTC': 'BTC 0.00001481',
#  'PRECO_RS': 'R$ 0,22',
#  'VARIACAO': '3,67 %',
#  'VM': 'R$ 224.693.536',
#  'VT': 'R$ 2.175.034',
#  '_id': ObjectId('5c7185f8a887625d640ee0c7')}
# {'ID': '70',
#  'NOME': 'Factom',
#  'PRECO_BTC': 'BTC 0.00168743',
#  'PRECO_RS': 'R$ 25,62',
#  'VARIACAO': '0,26 %',
#  'VM': 'R$ 224.047.903',
#  'VT': 'R$ 154.241',
#  '_id': ObjectId('5c7185f8a887625d640ee0c8')}
# {'ID': '100',
#  'NOME': 'Everipedia',
#  'PRECO_BTC': 'BTC 0.00000184',
#  'PRECO_RS': 'R$ 0,05',
#  'VARIACAO': '23,85 %',
#  'VM': 'R$ 223.893.659',
#  'VT': 'R$ 10.493.232',
#  '_id': ObjectId('5c7185f8a887625d640ee0c9')}
# {'ID': '71',
#  'NOME': 'MaidSafeCoin',
#  'PRECO_BTC': 'BTC 0.00003246',
#  'PRECO_RS': 'R$ 0,49',
#  'VARIACAO': '2,38 %',
#  'VM': 'R$ 223.045.184',
#  'VT': 'R$ 721.239',
#  '_id': ObjectId('5c7185f8a887625d640ee0ca')}
# {'ID': '60',
#  'NOME': 'PayPie',
#  'PRECO_BTC': 'BTC 0.00019487',
#  'PRECO_RS': 'R$ 2,67',
#  'VARIACAO': '0,00 %',
#  'VM': 'R$ 220.256.315',
#  'VT': 'R$ 2.444',
#  '_id': ObjectId('5c7185f8a887625d640ee0cb')}
# {'ID': '100',
#  'NOME': 'Cortex',
#  'PRECO_BTC': 'BTC 0.00005844',
#  'PRECO_RS': 'R$ 1,47',
#  'VARIACAO': '-5,17 %',
#  'VM': 'R$ 220.039.271',
#  'VT': 'R$ 66.505.862',
#  '_id': ObjectId('5c7185f8a887625d640ee0cc')}
# {'ID': '72',
#  'NOME': 'Aurora',
#  'PRECO_BTC': 'BTC 0.00000221',
#  'PRECO_RS': 'R$ 0,03',
#  'VARIACAO': '25,14 %',
#  'VM': 'R$ 218.684.308',
#  'VT': 'R$ 9.783.402',
#  '_id': ObjectId('5c7185f8a887625d640ee0cd')}
# {'ID': '100',
#  'NOME': 'BridgeCoin',
#  'PRECO_BTC': 'BTC 0.00029791',
#  'PRECO_RS': 'R$ 8,03',
#  'VARIACAO': '23,91 %',
#  'VM': 'R$ 216.704.392',
#  'VT': 'R$ 102.989',
#  '_id': ObjectId('5c7185f8a887625d640ee0ce')}
# {'ID': '100',
#  'NOME': 'RChain',
#  'PRECO_BTC': 'BTC 0.00002340',
#  'PRECO_RS': 'R$ 0,56',
#  'VARIACAO': '-0,97 %',
#  'VM': 'R$ 216.364.390',
#  'VT': 'R$ 1.995.671',
#  '_id': ObjectId('5c7185f8a887625d640ee0cf')}
# {'ID': '100',
#  'NOME': 'Noah Coin',
#  'PRECO_BTC': 'BTC 0.00000027',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '19,29 %',
#  'VM': 'R$ 214.551.908',
#  'VT': 'R$ 6.114.301',
#  '_id': ObjectId('5c7185f8a887625d640ee0d0')}
# {'ID': '100',
#  'NOME': 'Odyssey',
#  'PRECO_BTC': 'BTC 0.00000188',
#  'PRECO_RS': 'R$ 0,05',
#  'VARIACAO': '-3,15 %',
#  'VM': 'R$ 213.822.437',
#  'VT': 'R$ 24.502.705',
#  '_id': ObjectId('5c7185f8a887625d640ee0d1')}
# {'ID': '98',
#  'NOME': 'UNIVERSAL CASH',
#  'PRECO_BTC': 'BTC 0.00000098',
#  'PRECO_RS': 'R$ 0,03',
#  'VARIACAO': '397,07 %',
#  'VM': 'R$ 211.508.977',
#  'VT': 'R$ 264.259',
#  '_id': ObjectId('5c7185f8a887625d640ee0d2')}
# {'ID': '100',
#  'NOME': 'Peercoin',
#  'PRECO_BTC': 'BTC 0.00034660',
#  'PRECO_RS': 'R$ 8,45',
#  'VARIACAO': '-1,78 %',
#  'VM': 'R$ 210.564.887',
#  'VT': 'R$ 3.665.023',
#  '_id': ObjectId('5c7185f8a887625d640ee0d3')}
# {'ID': '61',
#  'NOME': 'FREE Coin',
#  'PRECO_BTC': 'BTC 0.00000000',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '2.095,43 %',
#  'VM': 'R$ 207.021.631',
#  'VT': 'R$ 19.634',
#  '_id': ObjectId('5c7185f8a887625d640ee0d4')}
# {'ID': '99',
#  'NOME': 'Bitcoin Interest',
#  'PRECO_BTC': 'BTC 0.00043270',
#  'PRECO_RS': 'R$ 11,25',
#  'VARIACAO': '100,47 %',
#  'VM': 'R$ 206.157.228',
#  'VT': 'R$ 346.683',
#  '_id': ObjectId('5c7185f8a887625d640ee0d5')}
# {'ID': '100',
#  'NOME': 'PRIZM',
#  'PRECO_BTC': 'BTC 0.00014564',
#  'PRECO_RS': 'R$ 3,63',
#  'VARIACAO': '24,73 %',
#  'VM': 'R$ 201.641.830',
#  'VT': 'R$ 140.098',
#  '_id': ObjectId('5c7185f8a887625d640ee0d6')}
# {'ID': '100',
#  'NOME': 'Bibox Token',
#  'PRECO_BTC': 'BTC 0.00007598',
#  'PRECO_RS': 'R$ 1,95',
#  'VARIACAO': '19,14 %',
#  'VM': 'R$ 199.572.867',
#  'VT': 'R$ 235.787.204',
#  '_id': ObjectId('5c7185f8a887625d640ee0d7')}
# {'ID': '83',
#  'NOME': 'SmartCash',
#  'PRECO_BTC': 'BTC 0.00000960',
#  'PRECO_RS': 'R$ 0,19',
#  'VARIACAO': '163,99 %',
#  'VM': 'R$ 199.263.919',
#  'VT': 'R$ 2.433.285',
#  '_id': ObjectId('5c7185f8a887625d640ee0d8')}
# {'ID': '100',
#  'NOME': 'Nexus',
#  'PRECO_BTC': 'BTC 0.00013082',
#  'PRECO_RS': 'R$ 3,40',
#  'VARIACAO': '-3,34 %',
#  'VM': 'R$ 199.003.751',
#  'VT': 'R$ 2.576.640',
#  '_id': ObjectId('5c7185f8a887625d640ee0d9')}
# {'ID': '73',
#  'NOME': 'HyperCash',
#  'PRECO_BTC': 'BTC 0.00029770',
#  'PRECO_RS': 'R$ 4,52',
#  'VARIACAO': '4,28 %',
#  'VM': 'R$ 196.749.114',
#  'VT': 'R$ 9.262.035',
#  '_id': ObjectId('5c7185f8a887625d640ee0da')}
# {'ID': '100',
#  'NOME': 'Groestlcoin',
#  'PRECO_BTC': 'BTC 0.00011037',
#  'PRECO_RS': 'R$ 2,69',
#  'VARIACAO': '96,70 %',
#  'VM': 'R$ 190.400.843',
#  'VT': 'R$ 84.101.941',
#  '_id': ObjectId('5c7185f8a887625d640ee0db')}
# {'ID': '71',
#  'NOME': 'Safe Exchange Coin',
#  'PRECO_BTC': 'BTC 0.00000885',
#  'PRECO_RS': 'R$ 0,12',
#  'VARIACAO': '536,27 %',
#  'VM': 'R$ 185.426.104',
#  'VT': 'R$ 45.288',
#  '_id': ObjectId('5c7185f8a887625d640ee0dc')}
# {'ID': '74',
#  'NOME': 'Crypto.com',
#  'PRECO_BTC': 'BTC 0.00074457',
#  'PRECO_RS': 'R$ 11,30',
#  'VARIACAO': '-0,41 %',
#  'VM': 'R$ 178.542.234',
#  'VT': 'R$ 10.908.611',
#  '_id': ObjectId('5c7185f8a887625d640ee0dd')}
# {'ID': '81',
#  'NOME': 'Veros',
#  'PRECO_BTC': 'BTC 0.00020403',
#  'PRECO_RS': 'R$ 3,33',
#  'VARIACAO': '34,04 %',
#  'VM': 'R$ 177.441.261',
#  'VT': 'R$ 10.557.122',
#  '_id': ObjectId('5c7185f8a887625d640ee0de')}
# {'ID': '76',
#  'NOME': 'SIRIN LABS Token',
#  'PRECO_BTC': 'BTC 0.00002443',
#  'PRECO_RS': 'R$ 0,36',
#  'VARIACAO': '131,45 %',
#  'VM': 'R$ 174.718.972',
#  'VT': 'R$ 6.954.732',
#  '_id': ObjectId('5c7185f8a887625d640ee0df')}
# {'ID': '75',
#  'NOME': 'Waltonchain',
#  'PRECO_BTC': 'BTC 0.00028005',
#  'PRECO_RS': 'R$ 4,24',
#  'VARIACAO': '4,91 %',
#  'VM': 'R$ 174.005.647',
#  'VT': 'R$ 12.069.557',
#  '_id': ObjectId('5c7185f8a887625d640ee0e0')}
# {'ID': '76',
#  'NOME': 'Loopring',
#  'PRECO_BTC': 'BTC 0.00001423',
#  'PRECO_RS': 'R$ 0,22',
#  'VARIACAO': '3,13 %',
#  'VM': 'R$ 170.136.431',
#  'VT': 'R$ 5.274.326',
#  '_id': ObjectId('5c7185f8a887625d640ee0e1')}
# {'ID': '77',
#  'NOME': 'PIVX',
#  'PRECO_BTC': 'BTC 0.00019692',
#  'PRECO_RS': 'R$ 2,99',
#  'VARIACAO': '1,99 %',
#  'VM': 'R$ 169.761.654',
#  'VT': 'R$ 741.367',
#  '_id': ObjectId('5c7185f8a887625d640ee0e2')}
# {'ID': '78',
#  'NOME': 'Project Pai',
#  'PRECO_BTC': 'BTC 0.00000792',
#  'PRECO_RS': 'R$ 0,12',
#  'VARIACAO': '6,29 %',
#  'VM': 'R$ 169.531.038',
#  'VT': 'R$ 20.837.557',
#  '_id': ObjectId('5c7185f8a887625d640ee0e3')}
# {'ID': '79',
#  'NOME': 'Insight Chain',
#  'PRECO_BTC': 'BTC 0.00006616',
#  'PRECO_RS': 'R$ 1,00',
#  'VARIACAO': '-1,00 %',
#  'VM': 'R$ 166.989.980',
#  'VT': 'R$ 16.020.340',
#  '_id': ObjectId('5c7185f8a887625d640ee0e4')}
# {'ID': '80',
#  'NOME': 'KuCoin Shares',
#  'PRECO_BTC': 'BTC 0.00011985',
#  'PRECO_RS': 'R$ 1,82',
#  'VARIACAO': '4,07 %',
#  'VM': 'R$ 163.653.610',
#  'VT': 'R$ 1.058.297',
#  '_id': ObjectId('5c7185f8a887625d640ee0e5')}
# {'ID': '81',
#  'NOME': 'Nexo',
#  'PRECO_BTC': 'BTC 0.00001926',
#  'PRECO_RS': 'R$ 0,29',
#  'VARIACAO': '7,99 %',
#  'VM': 'R$ 163.447.543',
#  'VT': 'R$ 17.996.279',
#  '_id': ObjectId('5c7185f8a887625d640ee0e6')}
# {'ID': '81',
#  'NOME': 'DEX',
#  'PRECO_BTC': 'BTC 0.00006236',
#  'PRECO_RS': 'R$ 0,84',
#  'VARIACAO': '211,89 %',
#  'VM': 'R$ 160.873.025',
#  'VT': 'R$ 459.270',
#  '_id': ObjectId('5c7185f8a887625d640ee0e7')}
# {'ID': '82',
#  'NOME': 'ODEM',
#  'PRECO_BTC': 'BTC 0.00004732',
#  'PRECO_RS': 'R$ 0,72',
#  'VARIACAO': '-2,60 %',
#  'VM': 'R$ 159.745.765',
#  'VT': 'R$ 2.188.093',
#  '_id': ObjectId('5c7185f8a887625d640ee0e8')}
# {'ID': '78',
#  'NOME': 'ARBITRAGE',
#  'PRECO_BTC': 'BTC 0.00263794',
#  'PRECO_RS': 'R$ 36,51',
#  'VARIACAO': '72,93 %',
#  'VM': 'R$ 159.165.574',
#  'VT': 'R$ 785.785',
#  '_id': ObjectId('5c7185f8a887625d640ee0e9')}
# {'ID': '83',
#  'NOME': 'Crypto.com Chain',
#  'PRECO_BTC': 'BTC 0.00000323',
#  'PRECO_RS': 'R$ 0,05',
#  'VARIACAO': '-0,96 %',
#  'VM': 'R$ 158.596.994',
#  'VT': 'R$ 2.528.956',
#  '_id': ObjectId('5c7185f8a887625d640ee0ea')}
# {'ID': '84',
#  'NOME': 'Linkey',
#  'PRECO_BTC': 'BTC 0.00020917',
#  'PRECO_RS': 'R$ 3,17',
#  'VARIACAO': '2,48 %',
#  'VM': 'R$ 158.493.704',
#  'VT': 'R$ 2.112.910',
#  '_id': ObjectId('5c7185f8a887625d640ee0eb')}
# {'ID': '85',
#  'NOME': 'Veritaseum',
#  'PRECO_BTC': 'BTC 0.00483200',
#  'PRECO_RS': 'R$ 73,36',
#  'VARIACAO': '4,53 %',
#  'VM': 'R$ 157.704.423',
#  'VT': 'R$ 7.982.634',
#  '_id': ObjectId('5c7185f8a887625d640ee0ec')}
# {'ID': '79',
#  'NOME': 'Maximine Coin',
#  'PRECO_BTC': 'BTC 0.00000289',
#  'PRECO_RS': 'R$ 0,04',
#  'VARIACAO': '8,33 %',
#  'VM': 'R$ 157.362.434',
#  'VT': 'R$ 3.711.356',
#  '_id': ObjectId('5c7185f8a887625d640ee0ed')}
# {'ID': '86',
#  'NOME': 'WAX',
#  'PRECO_BTC': 'BTC 0.00001107',
#  'PRECO_RS': 'R$ 0,17',
#  'VARIACAO': '-0,20 %',
#  'VM': 'R$ 157.230.971',
#  'VT': 'R$ 862.162',
#  '_id': ObjectId('5c7185f8a887625d640ee0ee')}
# {'ID': '87',
#  'NOME': 'Quant',
#  'PRECO_BTC': 'BTC 0.00103970',
#  'PRECO_RS': 'R$ 15,76',
#  'VARIACAO': '1,43 %',
#  'VM': 'R$ 154.052.632',
#  'VT': 'R$ 8.747.020',
#  '_id': ObjectId('5c7185f8a887625d640ee0ef')}
# {'ID': '88',
#  'NOME': 'QASH',
#  'PRECO_BTC': 'BTC 0.00002883',
#  'PRECO_RS': 'R$ 0,44',
#  'VARIACAO': '13,97 %',
#  'VM': 'R$ 152.911.934',
#  'VT': 'R$ 2.509.734',
#  '_id': ObjectId('5c7185f8a887625d640ee0f0')}
# {'ID': '87',
#  'NOME': 'MassGrid',
#  'PRECO_BTC': 'BTC 0.00018925',
#  'PRECO_RS': 'R$ 2,88',
#  'VARIACAO': '1.220,92 %',
#  'VM': 'R$ 152.707.319',
#  'VT': 'R$ 219.309',
#  '_id': ObjectId('5c7185f8a887625d640ee0f1')}
# {'ID': '89',
#  'NOME': 'GXChain',
#  'PRECO_BTC': 'BTC 0.00016658',
#  'PRECO_RS': 'R$ 2,53',
#  'VARIACAO': '6,57 %',
#  'VM': 'R$ 151.750.259',
#  'VT': 'R$ 36.597.627',
#  '_id': ObjectId('5c7185f9a887625d640ee0f2')}
# {'ID': '80',
#  'NOME': 'Restart Energy MWAT',
#  'PRECO_BTC': 'BTC 0.00002462',
#  'PRECO_RS': 'R$ 0,33',
#  'VARIACAO': '455,72 %',
#  'VM': 'R$ 150.949.303',
#  'VT': 'R$ 191.222',
#  '_id': ObjectId('5c7185f9a887625d640ee0f3')}
# {'ID': '90',
#  'NOME': 'Decentraland',
#  'PRECO_BTC': 'BTC 0.00000946',
#  'PRECO_RS': 'R$ 0,14',
#  'VARIACAO': '1,32 %',
#  'VM': 'R$ 150.816.950',
#  'VT': 'R$ 7.155.670',
#  '_id': ObjectId('5c7185f9a887625d640ee0f4')}
# {'ID': '91',
#  'NOME': 'MOAC',
#  'PRECO_BTC': 'BTC 0.00015921',
#  'PRECO_RS': 'R$ 2,41',
#  'VARIACAO': '2,37 %',
#  'VM': 'R$ 150.706.495',
#  'VT': 'R$ 184.187',
#  '_id': ObjectId('5c7185f9a887625d640ee0f5')}
# {'ID': '97',
#  'NOME': 'Enigma',
#  'PRECO_BTC': 'BTC 0.00011679',
#  'PRECO_RS': 'R$ 2,01',
#  'VARIACAO': '58,08 %',
#  'VM': 'R$ 150.520.820',
#  'VT': 'R$ 5.615.243',
#  '_id': ObjectId('5c7185f9a887625d640ee0f6')}
# {'ID': '92',
#  'NOME': 'aelf',
#  'PRECO_BTC': 'BTC 0.00003538',
#  'PRECO_RS': 'R$ 0,54',
#  'VARIACAO': '5,70 %',
#  'VM': 'R$ 150.148.099',
#  'VT': 'R$ 38.243.593',
#  '_id': ObjectId('5c7185f9a887625d640ee0f7')}
# {'ID': '93',
#  'NOME': 'Power Ledger',
#  'PRECO_BTC': 'BTC 0.00002445',
#  'PRECO_RS': 'R$ 0,37',
#  'VARIACAO': '3,72 %',
#  'VM': 'R$ 146.844.765',
#  'VT': 'R$ 6.150.794',
#  '_id': ObjectId('5c7185f9a887625d640ee0f8')}
# {'ID': '100',
#  'NOME': 'CyberMiles',
#  'PRECO_BTC': 'BTC 0.00001172',
#  'PRECO_RS': 'R$ 0,19',
#  'VARIACAO': '4,76 %',
#  'VM': 'R$ 146.504.751',
#  'VT': 'R$ 10.176.137',
#  '_id': ObjectId('5c7185f9a887625d640ee0f9')}
# {'ID': '94',
#  'NOME': 'Zcoin',
#  'PRECO_BTC': 'BTC 0.00139020',
#  'PRECO_RS': 'R$ 21,11',
#  'VARIACAO': '1,65 %',
#  'VM': 'R$ 144.806.041',
#  'VT': 'R$ 1.759.640',
#  '_id': ObjectId('5c7185f9a887625d640ee0fa')}
# {'ID': '95',
#  'NOME': 'ReddCoin',
#  'PRECO_BTC': 'BTC 0.00000033',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '3,17 %',
#  'VM': 'R$ 144.211.589',
#  'VT': 'R$ 264.082',
#  '_id': ObjectId('5c7185f9a887625d640ee0fb')}
# {'ID': '90',
#  'NOME': 'Etheera',
#  'PRECO_BTC': 'BTC 0.00000169',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '8.249,65 %',
#  'VM': 'R$ 142.486.317',
#  'VT': 'R$ 3.339',
#  '_id': ObjectId('5c7185f9a887625d640ee0fc')}
# {'ID': '100',
#  'NOME': 'BOScoin',
#  'PRECO_BTC': 'BTC 0.00001893',
#  'PRECO_RS': 'R$ 0,30',
#  'VARIACAO': '1,72 %',
#  'VM': 'R$ 139.061.003',
#  'VT': 'R$ 135.289',
#  '_id': ObjectId('5c7185f9a887625d640ee0fd')}
# {'ID': '100',
#  'NOME': 'Enjin Coin',
#  'PRECO_BTC': 'BTC 0.00001203',
#  'PRECO_RS': 'R$ 0,18',
#  'VARIACAO': '12,24 %',
#  'VM': 'R$ 136.448.696',
#  'VT': 'R$ 6.098.500',
#  '_id': ObjectId('5c7185f9a887625d640ee0fe')}
# {'ID': '96',
#  'NOME': 'Metaverse ETP',
#  'PRECO_BTC': 'BTC 0.00016265',
#  'PRECO_RS': 'R$ 2,47',
#  'VARIACAO': '3,73 %',
#  'VM': 'R$ 135.971.106',
#  'VT': 'R$ 4.184.463',
#  '_id': ObjectId('5c7185f9a887625d640ee0ff')}
# {'ID': '100',
#  'NOME': 'OneRoot Network',
#  'PRECO_BTC': 'BTC 0.00003414',
#  'PRECO_RS': 'R$ 0,49',
#  'VARIACAO': '2,64 %',
#  'VM': 'R$ 135.806.768',
#  'VT': 'R$ 21.795.806',
#  '_id': ObjectId('5c7185f9a887625d640ee100')}
# {'ID': '100',
#  'NOME': 'Dropil',
#  'PRECO_BTC': 'BTC 0.00000038',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '-9,12 %',
#  'VM': 'R$ 135.729.596',
#  'VT': 'R$ 1.130.144',
#  '_id': ObjectId('5c7185f9a887625d640ee101')}
# {'ID': '97',
#  'NOME': 'Bancor',
#  'PRECO_BTC': 'BTC 0.00014423',
#  'PRECO_RS': 'R$ 2,19',
#  'VARIACAO': '3,84 %',
#  'VM': 'R$ 134.992.271',
#  'VT': 'R$ 6.710.007',
#  '_id': ObjectId('5c7185f9a887625d640ee102')}
# {'ID': '98',
#  'NOME': 'Melon',
#  'PRECO_BTC': 'BTC 0.01106680',
#  'PRECO_RS': 'R$ 165,98',
#  'VARIACAO': '434,90 %',
#  'VM': 'R$ 134.862.883',
#  'VT': 'R$ 33.695',
#  '_id': ObjectId('5c7185f9a887625d640ee103')}
# {'ID': '98',
#  'NOME': 'TomoChain',
#  'PRECO_BTC': 'BTC 0.00014927',
#  'PRECO_RS': 'R$ 2,26',
#  'VARIACAO': '2,81 %',
#  'VM': 'R$ 133.535.567',
#  'VT': 'R$ 452.065',
#  '_id': ObjectId('5c7185f9a887625d640ee104')}
# {'ID': '100',
#  'NOME': 'ProximaX',
#  'PRECO_BTC': 'BTC 0.00000139',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '0,32 %',
#  'VM': 'R$ 133.297.684',
#  'VT': 'R$ 7.425.847',
#  '_id': ObjectId('5c7185f9a887625d640ee105')}
# {'ID': '99',
#  'NOME': 'MonaCoin',
#  'PRECO_BTC': 'BTC 0.00013313',
#  'PRECO_RS': 'R$ 2,02',
#  'VARIACAO': '0,97 %',
#  'VM': 'R$ 132.861.778',
#  'VT': 'R$ 362.770',
#  '_id': ObjectId('5c7185f9a887625d640ee106')}
# {'ID': '100',
#  'NOME': 'Santiment Network Token',
#  'PRECO_BTC': 'BTC 0.00013952',
#  'PRECO_RS': 'R$ 2,12',
#  'VARIACAO': '5,28 %',
#  'VM': 'R$ 132.737.854',
#  'VT': 'R$ 143.428',
#  '_id': ObjectId('5c7185f9a887625d640ee107')}
# {'ID': '97',
#  'NOME': 'Credo',
#  'PRECO_BTC': 'BTC 0.00001694',
#  'PRECO_RS': 'R$ 0,24',
#  'VARIACAO': '16,61 %',
#  'VM': 'R$ 132.571.178',
#  'VT': 'R$ 40.798',
#  '_id': ObjectId('5c7185f9a887625d640ee108')}
# {'ID': '100',
#  'NOME': 'Endor Protocol',
#  'PRECO_BTC': 'BTC 0.00001255',
#  'PRECO_RS': 'R$ 0,19',
#  'VARIACAO': '-6,14 %',
#  'VM': 'R$ 132.261.179',
#  'VT': 'R$ 92.668.092',
#  '_id': ObjectId('5c7185f9a887625d640ee109')}
# {'ID': '100',
#  'NOME': 'STASIS EURS',
#  'PRECO_BTC': 'BTC 0.00028221',
#  'PRECO_RS': 'R$ 4,26',
#  'VARIACAO': '-0,39 %',
#  'VM': 'R$ 131.933.686',
#  'VT': 'R$ 1.121.260',
#  '_id': ObjectId('5c7185f9a887625d640ee10a')}
# {'ID': '100',
#  'NOME': 'Mithril',
#  'PRECO_BTC': 'BTC 0.00001804',
#  'PRECO_RS': 'R$ 0,27',
#  'VARIACAO': '-0,88 %',
#  'VM': 'R$ 131.530.312',
#  'VT': 'R$ 15.829.212',
#  '_id': ObjectId('5c7185f9a887625d640ee10b')}
# {'ID': '97',
#  'NOME': 'Centrality',
#  'PRECO_BTC': 'BTC 0.00001097',
#  'PRECO_RS': 'R$ 0,16',
#  'VARIACAO': '13,83 %',
#  'VM': 'R$ 131.351.242',
#  'VT': 'R$ 41.737',
#  '_id': ObjectId('5c7185f9a887625d640ee10c')}
# {'ID': '98',
#  'NOME': 'LATOKEN',
#  'PRECO_BTC': 'BTC 0.00002541',
#  'PRECO_RS': 'R$ 0,38',
#  'VARIACAO': '16,49 %',
#  'VM': 'R$ 130.701.310',
#  'VT': 'R$ 2.466.060',
#  '_id': ObjectId('5c7185f9a887625d640ee10d')}
# {'ID': '100',
#  'NOME': 'XYO Network',
#  'PRECO_BTC': 'BTC 0.00000157',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '19,50 %',
#  'VM': 'R$ 130.248.548',
#  'VT': 'R$ 552.311',
#  '_id': ObjectId('5c7185f9a887625d640ee10e')}
# {'ID': '100',
#  'NOME': 'Storj',
#  'PRECO_BTC': 'BTC 0.00006388',
#  'PRECO_RS': 'R$ 0,95',
#  'VARIACAO': '7,79 %',
#  'VM': 'R$ 129.548.972',
#  'VT': 'R$ 15.762.129',
#  '_id': ObjectId('5c7185f9a887625d640ee10f')}
# {'ID': '100',
#  'NOME': 'Ravencoin',
#  'PRECO_BTC': 'BTC 0.00000292',
#  'PRECO_RS': 'R$ 0,04',
#  'VARIACAO': '7,01 %',
#  'VM': 'R$ 129.193.710',
#  'VT': 'R$ 23.505.318',
#  '_id': ObjectId('5c7185f9a887625d640ee110')}
# {'ID': '100',
#  'NOME': 'Apollo Currency',
#  'PRECO_BTC': 'BTC 0.00000064',
#  'PRECO_RS': 'R$ 0,01',
#  'VARIACAO': '17,55 %',
#  'VM': 'R$ 128.265.961',
#  'VT': 'R$ 6.524.475',
#  '_id': ObjectId('5c7185f9a887625d640ee111')}
# {'ID': '100',
#  'NOME': 'Aion',
#  'PRECO_BTC': 'BTC 0.00002926',
#  'PRECO_RS': 'R$ 0,44',
#  'VARIACAO': '1,01 %',
#  'VM': 'R$ 127.713.931',
#  'VT': 'R$ 5.575.861',
#  '_id': ObjectId('5c7185f9a887625d640ee112')}
# {'ID': '86',
#  'NOME': 'Unobtanium',
#  'PRECO_BTC': 'BTC 0.04955135',
#  'PRECO_RS': 'R$ 637,43',
#  'VARIACAO': '139,73 %',
#  'VM': 'R$ 127.408.721',
#  'VT': 'R$ 237.685',
#  '_id': ObjectId('5c7185f9a887625d640ee113')}
# {'ID': '100',
#  'NOME': 'FunFair',
#  'PRECO_BTC': 'BTC 0.00000170',
#  'PRECO_RS': 'R$ 0,02',
#  'VARIACAO': '30,81 %',
#  'VM': 'R$ 126.620.163',
#  'VT': 'R$ 12.374.495',
#  '_id': ObjectId('5c7185f9a887625d640ee114')}
# {'ID': '100',
#  'NOME': 'NULS',
#  'PRECO_BTC': 'BTC 0.00014807',
#  'PRECO_RS': 'R$ 2,00',
#  'VARIACAO': '32,70 %',
#  'VM': 'R$ 126.115.905',
#  'VT': 'R$ 395.966.906',
#  '_id': ObjectId('5c7185f9a887625d640ee115')}
# {'ID': '100',
#  'NOME': 'Horizen',
#  'PRECO_BTC': 'BTC 0.00163301',
#  'PRECO_RS': 'R$ 23,08',
#  'VARIACAO': '7,93 %',
#  'VM': 'R$ 126.068.914',
#  'VT': 'R$ 7.728.938',
#  '_id': ObjectId('5c7185f9a887625d640ee116')}
# {'ID': '99',
#  'NOME': 'Radium',
#  'PRECO_BTC': 'BTC 0.00236600',
#  'PRECO_RS': 'R$ 34,78',
#  'VARIACAO': '1.239,78 %',
#  'VM': 'R$ 123.879.947',
#  'VT': 'R$ 26.432',
#  '_id': ObjectId('5c7185f9a887625d640ee117')}
# {'ID': '100',
#  'NOME': 'Dent',
#  'PRECO_BTC': 'BTC 0.00000026',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '2,10 %',
#  'VM': 'R$ 123.673.876',
#  'VT': 'R$ 3.465.115',
#  '_id': ObjectId('5c7185f9a887625d640ee118')}
# {'ID': '99',
#  'NOME': 'Timicoin',
#  'PRECO_BTC': 'BTC 0.00002653',
#  'PRECO_RS': 'R$ 0,39',
#  'VARIACAO': '563,53 %',
#  'VM': 'R$ 123.425.361',
#  'VT': 'R$ 143.618',
#  '_id': ObjectId('5c7185f9a887625d640ee119')}
# {'ID': '100',
#  'NOME': 'Syscoin',
#  'PRECO_BTC': 'BTC 0.00001513',
#  'PRECO_RS': 'R$ 0,22',
#  'VARIACAO': '11,23 %',
#  'VM': 'R$ 123.090.590',
#  'VT': 'R$ 9.731.460',
#  '_id': ObjectId('5c7185f9a887625d640ee11a')}
# {'ID': '100',
#  'NOME': 'Moss Coin',
#  'PRECO_BTC': 'BTC 0.00003621',
#  'PRECO_RS': 'R$ 0,53',
#  'VARIACAO': '232,76 %',
#  'VM': 'R$ 122.988.642',
#  'VT': 'R$ 88.995.910',
#  '_id': ObjectId('5c7185f9a887625d640ee11b')}
# {'ID': '97',
#  'NOME': 'Kin',
#  'PRECO_BTC': 'BTC 0.00000001',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '42,12 %',
#  'VM': 'R$ 122.507.884',
#  'VT': 'R$ 2.051.154',
#  '_id': ObjectId('5c7185f9a887625d640ee11c')}
# {'ID': '100',
#  'NOME': 'Wanchain',
#  'PRECO_BTC': 'BTC 0.00007721',
#  'PRECO_RS': 'R$ 1,15',
#  'VARIACAO': '1,46 %',
#  'VM': 'R$ 121.588.886',
#  'VT': 'R$ 7.190.933',
#  '_id': ObjectId('5c7185f9a887625d640ee11d')}
# {'ID': '100',
#  'NOME': 'Optimal Shelf Availability Token',
#  'PRECO_BTC': 'BTC 0.00001026',
#  'PRECO_RS': 'R$ 0,14',
#  'VARIACAO': '-17,52 %',
#  'VM': 'R$ 121.457.766',
#  'VT': 'R$ 4.974.501',
#  '_id': ObjectId('5c7185f9a887625d640ee11e')}
# {'ID': '100',
#  'NOME': 'DigixDAO',
#  'PRECO_BTC': 'BTC 0.00409331',
#  'PRECO_RS': 'R$ 60,61',
#  'VARIACAO': '-0,80 %',
#  'VM': 'R$ 121.216.741',
#  'VT': 'R$ 991.102',
#  '_id': ObjectId('5c7185f9a887625d640ee11f')}
# {'ID': '85',
#  'NOME': 'GXChain',
#  'PRECO_BTC': 'BTC 0.00015723',
#  'PRECO_RS': 'R$ 2,01',
#  'VARIACAO': '1,96 %',
#  'VM': 'R$ 120.452.639',
#  'VT': 'R$ 6.217.079',
#  '_id': ObjectId('5c7185f9a887625d640ee120')}
# {'ID': '99',
#  'NOME': 'Bitcoiin',
#  'PRECO_BTC': 'BTC 0.00017619',
#  'PRECO_RS': 'R$ 2,41',
#  'VARIACAO': '-2,05 %',
#  'VM': 'R$ 119.120.605',
#  'VT': 'R$ 3.154.140',
#  '_id': ObjectId('5c7185f9a887625d640ee121')}
# {'ID': '100',
#  'NOME': 'Particl',
#  'PRECO_BTC': 'BTC 0.00107796',
#  'PRECO_RS': 'R$ 14,67',
#  'VARIACAO': '52,35 %',
#  'VM': 'R$ 118.351.022',
#  'VT': 'R$ 3.381.567',
#  '_id': ObjectId('5c7185f9a887625d640ee122')}
# {'ID': '100',
#  'NOME': 'Digitex Futures',
#  'PRECO_BTC': 'BTC 0.00001162',
#  'PRECO_RS': 'R$ 0,16',
#  'VARIACAO': '-4,64 %',
#  'VM': 'R$ 116.219.794',
#  'VT': 'R$ 1.594.447',
#  '_id': ObjectId('5c7185f9a887625d640ee123')}
# {'ID': '100',
#  'NOME': 'QuarkChain',
#  'PRECO_BTC': 'BTC 0.00001074',
#  'PRECO_RS': 'R$ 0,14',
#  'VARIACAO': '3,88 %',
#  'VM': 'R$ 115.788.476',
#  'VT': 'R$ 211.960.323',
#  '_id': ObjectId('5c7185f9a887625d640ee124')}
# {'ID': '100',
#  'NOME': 'Gold Bits Coin',
#  'PRECO_BTC': 'BTC 0.00007948',
#  'PRECO_RS': 'R$ 1,09',
#  'VARIACAO': '31,04 %',
#  'VM': 'R$ 115.673.607',
#  'VT': 'R$ 76.345',
#  '_id': ObjectId('5c7185f9a887625d640ee125')}
# {'ID': '100',
#  'NOME': 'Gas',
#  'PRECO_BTC': 'BTC 0.00085202',
#  'PRECO_RS': 'R$ 11,42',
#  'VARIACAO': '43,13 %',
#  'VM': 'R$ 115.616.395',
#  'VT': 'R$ 158.352.083',
#  '_id': ObjectId('5c7185f9a887625d640ee126')}
# {'ID': '100',
#  'NOME': 'Elastos',
#  'PRECO_BTC': 'BTC 0.00057741',
#  'PRECO_RS': 'R$ 7,86',
#  'VARIACAO': '-1,35 %',
#  'VM': 'R$ 114.560.706',
#  'VT': 'R$ 6.681.729',
#  '_id': ObjectId('5c7185f9a887625d640ee127')}
# {'ID': '100',
#  'NOME': 'Polymath',
#  'PRECO_BTC': 'BTC 0.00002555',
#  'PRECO_RS': 'R$ 0,35',
#  'VARIACAO': '5,86 %',
#  'VM': 'R$ 114.174.433',
#  'VT': 'R$ 18.173.519',
#  '_id': ObjectId('5c7185f9a887625d640ee128')}
# {'ID': '100',
#  'NOME': 'Nxt',
#  'PRECO_BTC': 'BTC 0.00000847',
#  'PRECO_RS': 'R$ 0,11',
#  'VARIACAO': '-1,29 %',
#  'VM': 'R$ 114.048.561',
#  'VT': 'R$ 1.742.493',
#  '_id': ObjectId('5c7185f9a887625d640ee129')}
# {'ID': '100',
#  'NOME': 'Bitcoin Private',
#  'PRECO_BTC': 'BTC 0.00040848',
#  'PRECO_RS': 'R$ 5,54',
#  'VARIACAO': '-1,79 %',
#  'VM': 'R$ 113.697.333',
#  'VT': 'R$ 355.829',
#  '_id': ObjectId('5c7185f9a887625d640ee12a')}
# {'ID': '100',
#  'NOME': 'Dentacoin',
#  'PRECO_BTC': 'BTC 0.00000003',
#  'PRECO_RS': 'R$ 0,00',
#  'VARIACAO': '-12,57 %',
#  'VM': 'R$ 112.019.399',
#  'VT': 'R$ 922.081',
#  '_id': ObjectId('5c7185f9a887625d640ee12b')}
# {'ID': '100',
#  'NOME': 'Vertcoin',
#  'PRECO_BTC': 'BTC 0.00017246',
#  'PRECO_RS': 'R$ 2,32',
#  'VARIACAO': '120,60 %',
#  'VM': 'R$ 111.763.723',
#  'VT': 'R$ 85.378.004',
#  '_id': ObjectId('5c7185f9a887625d640ee12c')}
# {'ID': '99',
#  'NOME': 'Breezecoin',
#  'PRECO_BTC': 'BTC 0.00021978',
#  'PRECO_RS': 'R$ 2,80',
#  'VARIACAO': '242,05 %',
#  'VM': 'R$ 109.946.820',
#  'VT': 'R$ 43.041',
#  '_id': ObjectId('5c7185f9a887625d640ee12d')}
# {'ID': '99',
#  'NOME': 'Nebulas',
#  'PRECO_BTC': 'BTC 0.00018239',
#  'PRECO_RS': 'R$ 2,40',
#  'VARIACAO': '4,15 %',
#  'VM': 'R$ 109.398.475',
#  'VT': 'R$ 15.678.297',
#  '_id': ObjectId('5c7185f9a887625d640ee12e')}
# {'ID': '100',
#  'NOME': 'Buggyra Coin Zero',
#  'PRECO_BTC': 'BTC 0.00000496',
#  'PRECO_RS': 'R$ 0,06',
#  'VARIACAO': '17,11 %',
#  'VM': 'R$ 105.644.908',
#  'VT': 'R$ 132.940',
#  '_id': ObjectId('5c7185f9a887625d640ee12f')}
# {'ID': '100',
#  'NOME': 'MobileGo',
#  'PRECO_BTC': 'BTC 0.00008313',
#  'PRECO_RS': 'R$ 1,05',
#  'VARIACAO': '-2,38 %',
#  'VM': 'R$ 104.598.807',
#  'VT': 'R$ 32.146.255',
#  '_id': ObjectId('5c7185f9a887625d640ee130')}
# {'ID': '100',
#  'NOME': 'Everus',
#  'PRECO_BTC': 'BTC 0.00001800',
#  'PRECO_RS': 'R$ 0,23',
#  'VARIACAO': '-1,23 %',
#  'VM': 'R$ 104.504.906',
#  'VT': 'R$ 79.522',
#  '_id': ObjectId('5c7185f9a887625d640ee131')}
# {'ID': '100',
#  'NOME': 'Loom Network',
#  'PRECO_BTC': 'BTC 0.00001288',
#  'PRECO_RS': 'R$ 0,16',
#  'VARIACAO': '13,83 %',
#  'VM': 'R$ 104.100.155',
#  'VT': 'R$ 8.927.658',
#  '_id': ObjectId('5c7185f9a887625d640ee132')}
# {'ID': '100',
#  'NOME': 'TenX',
#  'PRECO_BTC': 'BTC 0.00007166',
#  'PRECO_RS': 'R$ 0,91',
#  'VARIACAO': '-2,22 %',
#  'VM': 'R$ 103.686.667',
#  'VT': 'R$ 485.749',
#  '_id': ObjectId('5c7185f9a887625d640ee133')}
# <bound method MongoClient.close of MongoClient(host=['10.52.51.28:27017'], document_class=dict, tz_aware=False, connect=True)>
