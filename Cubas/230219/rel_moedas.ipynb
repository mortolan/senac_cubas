# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
import bson
import pprint
from bson.son import SON

client = MongoClient('10.52.51.28', 27017)
for document in client.cubas.marcio.find({}):
    
    pprint.pprint(document)
    
client.close
# Out:
# {'ID': '1',
#  'NOME': 'Bitcoin',
#  'PRECO_BTC': 'BTC 1.00000000',
#  'PRECO_RS': 'R$ 15.370,38',
#  'VARIACAO': '2,76 %',
#  'VM': 'R$ 269.817.489.214',
#  'VT': 'R$ 30.189.576.042',
#  '_id': ObjectId('5c7189a7a887625d640ee138')}
# {'ID': '2',
#  'NOME': 'Ethereum',
#  'PRECO_BTC': 'BTC 0.03815910',
#  'PRECO_RS': 'R$ 585,90',
#  'VARIACAO': '5,07 %',
#  'VM': 'R$ 61.507.349.069',
#  'VT': 'R$ 15.281.794.520',
#  '_id': ObjectId('5c7189a7a887625d640ee139')}
# {'ID': '3',
#  'NOME': 'XRP',
#  'PRECO_BTC': 'BTC 0.00008011',
#  'PRECO_RS': 'R$ 1,23',
#  'VARIACAO': '1,95 %',
#  'VM': 'R$ 50.877.959.316',
#  'VT': 'R$ 2.015.558.831',
#  '_id': ObjectId('5c7189a7a887625d640ee13a')}
# {'ID': '4',
#  'NOME': 'EOS',
#  'PRECO_BTC': 'BTC 0.00099804',
#  'PRECO_RS': 'R$ 15,32',
#  'VARIACAO': '5,32 %',
#  'VM': 'R$ 13.887.400.136',
#  'VT': 'R$ 4.914.005.400',
#  '_id': ObjectId('5c7189a7a887625d640ee13b')}
# {'ID': '5',
#  'NOME': 'Litecoin',
#  'PRECO_BTC': 'BTC 0.01256220',
# ...
