# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
import bson
import pprint
from bson.son import SON

print("Relatorio Cotação Crypto Moedas")
print("   ")

client = MongoClient('10.52.51.28', 27017)
for document in client.cubas.marcio.find({}):
    
    print("ID ............: ",document["ID"])
    print("Nome ..........: ",document["NOME"])
    print("Valor Mercado .: ",document["VM"])
    print("Preço R$ ......: ",document["PRECO_RS"])
    print("Preço BTC .....: ",document["PRECO_BTC"])
    print("Volume Total ..: ",document["VT"])
    print("Variação 24Hrs : ",document["VARIACAO"])
    print ("--------------------------------------------------")
    
client.close
# Out:
# Relatorio Cotação Crypto Moedas
#
# ID ............:  1
# Nome ..........:  Bitcoin
# Valor Mercado .:  R$ 269.817.489.214
# Preço R$ ......:  R$ 15.370,38
# Preço BTC .....:  BTC 1.00000000
# Volume Total ..:  R$ 30.189.576.042
# Variação 24Hrs :  2,76 %
# --------------------------------------------------
# ID ............:  2
# Nome ..........:  Ethereum
# Valor Mercado .:  R$ 61.507.349.069
# Preço R$ ......:  R$ 585,90
# Preço BTC .....:  BTC 0.03815910
# Volume Total ..:  R$ 15.281.794.520
# Variação 24Hrs :  5,07 %
# --------------------------------------------------
# ID ............:  3
# Nome ..........:  XRP
# Valor Mercado .:  R$ 50.877.959.316
# Preço R$ ......:  R$ 1,23
# Preço BTC .....:  BTC 0.00008011
# Volume Total ..:  R$ 2.015.558.831
# Variação 24Hrs :  1,95 %
# --------------------------------------------------
# ID ............:  4
# Nome ..........:  EOS
# Valor Mercado .:  R$ 13.887.400.136
# Preço R$ ......:  R$ 15,32
# Preço BTC .....:  BTC 0.00099804
# ...
